# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\HARISH\Desktop\Project -MSD\dataset.csv')

# %%
data.describe()
# Out:
#          Unnamed: 0         price
# count  7.349575e+06  7.349575e+06
# mean   3.674787e+06  1.784788e+02
# std    2.121640e+06  4.171807e+02
# min    0.000000e+00 -1.000000e+00
# 25%    1.837394e+06 -1.000000e+00
# 50%    3.674787e+06 -1.000000e+00
# 75%    5.512180e+06  9.900000e+01
# max    7.349574e+06  4.499000e+03

# %%
data.dropna(subset = ['Ontology'], inplace = True)

# %%
data.head(20)
# Out:
#     Unnamed: 0        Date                                  uuid  userevent  \
# 0            0  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 1            1  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 2            2  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 3            3  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 4            4  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 5            5  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 6            6  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart
# 7            7  2019-01-30  0094e7d4-df53-407d-9d0a-30d7371593da  addToCart
# 8            8  2019-01-29  009b1a92-9416-4acf-b194-dfde2042b062  addToCart
# 9            9  2019-01-14  00b86337-8a95-4f9c-84af-b4a5ca99609e  addToCart
# 10          10  2019-01-14  00b86337-8a95-4f9c-84af-b4a5ca99609e  addToCart
# ...

# %%
data
# Out:
#          Unnamed: 0        Date                                  uuid  \
# 0                 0  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 1                 1  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 2                 2  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 3                 3  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 4                 4  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# ...             ...         ...                                   ...
# 7349560     7349560  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2
# 7349561     7349561  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2
# 7349570     7349570  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
# 7349571     7349571  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
# 7349572     7349572  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
#
#          userevent  price        product_id                  Ontology
# ...

# %%
data[['people','category','mainproduct','product']] = data.Ontology.str.split(">",expand=True,)

# %%
data
# Out:
#          Unnamed: 0        Date                                  uuid  \
# 0                 0  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 1                 1  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 2                 2  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 3                 3  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# 4                 4  2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b
# ...             ...         ...                                   ...
# 7349560     7349560  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2
# 7349561     7349561  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2
# 7349570     7349570  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
# 7349571     7349571  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
# 7349572     7349572  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3
#
#          userevent  price        product_id                  Ontology people  \
# ...

# %%
data.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
#Removing the rows that has -1
data.drop(data.loc[data['price']==-1].index, inplace=True)

# %%
data
# Out:
#                Date                                  uuid  userevent  price  \
# 0        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 1        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 2        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 3        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    117
# 4        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    117
# ...             ...                                   ...        ...    ...
# 7349560  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2   pageView    699
# 7349561  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2   pageView    899
# 7349570  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
# 7349571  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
# 7349572  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
#
# ...

# %%
data.drop(['Ontology'],axis =1,inplace = True)

# %%
data
# Out:
#                Date                                  uuid  userevent  price  \
# 0        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 1        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 2        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    337
# 3        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    117
# 4        2019-01-14  007e188b-63b2-4c0b-9c74-2eb5a4cb1d9b  addToCart    117
# ...             ...                                   ...        ...    ...
# 7349560  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2   pageView    699
# 7349561  2019-07-25  0babc325-1a0f-4894-abce-92a9786570c2   pageView    899
# 7349570  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
# 7349571  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
# 7349572  2019-07-29  97c5469a-0337-49c7-8b11-f2838df58aa3   pageView   1399
#
# ...
