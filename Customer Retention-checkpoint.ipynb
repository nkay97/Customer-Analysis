# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\HARISH\Desktop\Project -MSD\gaindataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Date                                  uuid  \
# 0         893           934  2019-03-01  0030a650-2d4b-4ea0-91d9-3b89657f6900
# 1        1900          1965  2019-05-01  006b9c36-8a2b-47b5-86b6-c91bc3556f7e
# 2        3097          3191  2019-05-20  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f
# 3        3109          3203  2019-05-17  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f
# 4        3117          3211  2019-05-17  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f
#
#   userevent  price        product_id people category  mainproduct
# 0       buy    899  ST089SH61SKSDFMX  women    shoes      sandals
# 1       buy    499  VA625SH93MPMDFMX    men    shoes     sneakers
# 2       buy   1299  TI778SH92OSHDFMX    men    shoes      booties
# 3       buy    583  LE063AT20MOLDFMX    men  topwear  sweatshirts
# 4       buy   1299  TI778SH92OSHDFMX    men    shoes      booties

# %%
data.drop(['Unnamed: 0'],axis = 1,inplace = True)
data.drop(['Unnamed: 0.1'],axis = 1,inplace = True)

# %%
data.head()
# Out:
#          Date                                  uuid userevent  price  \
# 0  2019-03-01  0030a650-2d4b-4ea0-91d9-3b89657f6900       buy    899
# 1  2019-05-01  006b9c36-8a2b-47b5-86b6-c91bc3556f7e       buy    499
# 2  2019-05-20  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f       buy   1299
# 3  2019-05-17  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f       buy    583
# 4  2019-05-17  00aa5e1c-0588-4f2a-94e9-ec68ff79f67f       buy   1299
#
#          product_id people category  mainproduct
# 0  ST089SH61SKSDFMX  women    shoes      sandals
# 1  VA625SH93MPMDFMX    men    shoes     sneakers
# 2  TI778SH92OSHDFMX    men    shoes      booties
# 3  LE063AT20MOLDFMX    men  topwear  sweatshirts
# 4  TI778SH92OSHDFMX    men    shoes      booties

# %%
data_user_purchase = data.groupby(['uuid','Date'])['price'].sum().reset_index()

# %%
data_user_purchase
# Out:
#                                       uuid        Date  price
# 0     0030a650-2d4b-4ea0-91d9-3b89657f6900  2019-03-01    899
# 1     006b9c36-8a2b-47b5-86b6-c91bc3556f7e  2019-05-01    499
# 2     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f  2019-05-17   1882
# 3     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f  2019-05-20   1299
# 4     00bb365d-06b1-4090-8025-7002a31e44b7  2019-02-13   1299
# ...                                    ...         ...    ...
# 3235  ffabfa3d-e92f-49cf-84fd-61ac48c1da75  2019-04-01    699
# 3236  ffc2e80c-d0bf-4dba-bf9a-3544d5a928d0  2019-06-01    998
# 3237  ffea8441-b7ac-4a06-a472-3411d4e3e0fb  2019-04-16    897
# 3238  ffea8441-b7ac-4a06-a472-3411d4e3e0fb  2019-04-28    976
# 3239  fffbd684-95cc-46b9-9e60-152ae270ade0  2019-03-01   2794
#
# [3240 rows x 3 columns]

# %%
Total_Revenue = data_user_purchase['price'].sum(axis = 0, skipna = True)

# %%
Total_Revenue
# Out:
# 4549530

# %%
data_user_purchase['Date']= pd.to_datetime(data_user_purchase['Date'])

# %%
data_user_purchase['month_of_date'] = data_user_purchase['Date'].dt.month

# %%
data_user_purchase
# Out:
#                                       uuid       Date  price  month_of_date
# 0     0030a650-2d4b-4ea0-91d9-3b89657f6900 2019-03-01    899              3
# 1     006b9c36-8a2b-47b5-86b6-c91bc3556f7e 2019-05-01    499              5
# 2     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-17   1882              5
# 3     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-20   1299              5
# 4     00bb365d-06b1-4090-8025-7002a31e44b7 2019-02-13   1299              2
# ...                                    ...        ...    ...            ...
# 3235  ffabfa3d-e92f-49cf-84fd-61ac48c1da75 2019-04-01    699              4
# 3236  ffc2e80c-d0bf-4dba-bf9a-3544d5a928d0 2019-06-01    998              6
# 3237  ffea8441-b7ac-4a06-a472-3411d4e3e0fb 2019-04-16    897              4
# 3238  ffea8441-b7ac-4a06-a472-3411d4e3e0fb 2019-04-28    976              4
# 3239  fffbd684-95cc-46b9-9e60-152ae270ade0 2019-03-01   2794              3
#
# [3240 rows x 4 columns]

# %%
df_sales = data_user_purchase

# %%
df_sales
# Out:
#                                       uuid       Date  price  month_of_date
# 0     0030a650-2d4b-4ea0-91d9-3b89657f6900 2019-03-01    899              3
# 1     006b9c36-8a2b-47b5-86b6-c91bc3556f7e 2019-05-01    499              5
# 2     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-17   1882              5
# 3     00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-20   1299              5
# 4     00bb365d-06b1-4090-8025-7002a31e44b7 2019-02-13   1299              2
# ...                                    ...        ...    ...            ...
# 3235  ffabfa3d-e92f-49cf-84fd-61ac48c1da75 2019-04-01    699              4
# 3236  ffc2e80c-d0bf-4dba-bf9a-3544d5a928d0 2019-06-01    998              6
# 3237  ffea8441-b7ac-4a06-a472-3411d4e3e0fb 2019-04-16    897              4
# 3238  ffea8441-b7ac-4a06-a472-3411d4e3e0fb 2019-04-28    976              4
# 3239  fffbd684-95cc-46b9-9e60-152ae270ade0 2019-03-01   2794              3
#
# [3240 rows x 4 columns]

# %%
df_sales = df_sales.groupby(['month_of_date'])['price'].sum().reset_index()

# %%
df_sales
# Out:
#    month_of_date    price
# 0              1   503481
# 1              2   493528
# 2              3   635711
# 3              4   810801
# 4              5  1970525
# 5              6   135484

# %%
plt.plot(df_sales['month_of_date'],df_sales['price'])
plt.show()

# %%
df = data_user_purchase[data_user_purchase.duplicated(subset=['uuid'], keep=False)]

# %%
df.head(20)
# Out:
#                                     uuid       Date  price  month_of_date
# 2   00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-17   1882              5
# 3   00aa5e1c-0588-4f2a-94e9-ec68ff79f67f 2019-05-20   1299              5
# 11  015b91c2-e603-408d-97e5-c4eb8f212d48 2019-05-13    541              5
# 12  015b91c2-e603-408d-97e5-c4eb8f212d48 2019-05-15    375              5
# 20  01ee435c-5a27-4737-a59d-61f3bed66662 2019-05-17   2412              5
# 21  01ee435c-5a27-4737-a59d-61f3bed66662 2019-05-27   2598              5
# 22  01ee435c-5a27-4737-a59d-61f3bed66662 2019-05-29   2894              5
# 30  02eea9e3-2d51-40e5-8b9a-f9eb30d7415a 2019-05-03   6573              5
# 31  02eea9e3-2d51-40e5-8b9a-f9eb30d7415a 2019-05-13    449              5
# 46  04242388-33e7-4971-a484-8820622c4fd7 2019-02-07    599              2
# 47  04242388-33e7-4971-a484-8820622c4fd7 2019-03-28    499              3
# 48  04242388-33e7-4971-a484-8820622c4fd7 2019-05-29   1198              5
# ...

# %%
gain_Revenue = df['price'].sum(axis = 0, skipna = True)

# %%
gain_Revenue
# Out:
# 1233929

# %%
#df.to_csv(r'C:\Users\HARISH\Desktop\Project -MSD\retaindataset.csv')
